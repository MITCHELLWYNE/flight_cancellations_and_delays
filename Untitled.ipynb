# %%
import pandas as pd
import random
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
heatmap_data = pd.read_csv('Airline_Delay_Cause 2022.csv')
heatmap_data.head()
# Out:
#    year  month carrier       carrier_name airport  \
# 0  2022     12      9E  Endeavor Air Inc.     ABE
# 1  2022     12      9E  Endeavor Air Inc.     ABY
# 2  2022     12      9E  Endeavor Air Inc.     AEX
# 3  2022     12      9E  Endeavor Air Inc.     AGS
# 4  2022     12      9E  Endeavor Air Inc.     ALB
#
#                                         airport_name  arr_flights  arr_del15  \
# 0  Allentown/Bethlehem/Easton, PA: Lehigh Valley ...         27.0        7.0
# 1             Albany, GA: Southwest Georgia Regional         69.0        3.0
# 2           Alexandria, LA: Alexandria International         62.0       14.0
# 3        Augusta, GA: Augusta Regional at Bush Field         47.0       10.0
# 4                   Albany, NY: Albany International        131.0       34.0
#
#    carrier_ct  weather_ct  ...  security_ct  late_aircraft_ct  arr_cancelled  \
# 0        4.37        0.00  ...          0.0              0.53            0.0
# ...

# %%
del_canc_col = ['arr_flights', 'arr_del15', "arr_cancelled"]
del_canc_col = heatmap_data[del_canc_col]
del_canc_col.head()
# Out:
#    arr_flights  arr_del15  arr_cancelled
# 0         27.0        7.0            0.0
# 1         69.0        3.0            0.0
# 2         62.0       14.0            0.0
# 3         47.0       10.0            0.0
# 4        131.0       34.0            7.0

# %%
del_canc_col.dtypes
# Out:
# arr_flights      float64
# arr_del15        float64
# arr_cancelled    float64
# dtype: object

# %%
sns.heatmap(del_canc_col, cmap='hot', annot=True, fmt=".3f")
plt.show()
